# %% [markdown]
# # Nintendo

# %% [markdown]
# Founded in 1889 as Nintendo Karuta producing handmade hanafuda playing cards, Nintendo Co., Ltd is a Japanese multinational video game company headquarted in Kyoto which now releases both video games and video game consoles.
#
# Its first console, the Color TV-Game was distribute in 1977 and the company gained international recognition with the release of Donkey Kong in 1981 and the Nintendo Entertainment System and Super Mario Bros in 1985.
#
# Some of its most successful consoles in the video game industry include the Game Boy, the Super Nintendo Entertainment System, the Nintendo DS, the Wii and the Switch. It has also created numerous major franchises such as Mario, Donkey Kong, The Legend of Zelda, Pokémon, Kirby, Metroid, Fire Emblem, Animal Crossing, Splatoon, Star Fox, Xenoblade Chronicles, and Super Smash Bros.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
clean_df = pd.read_csv("/Users/jojotan/Documents/Portfolio/Video_Games/clean_vgsales.csv")
clean_df = clean_df.astype({"Year": int})

# %%
nintendo_df = clean_df[clean_df['Main Publisher'] == 'Nintendo']

# %%
nintendo_df['Franchise'] = pd.np.where(nintendo_df.Name.str.contains('1080'), 'Y', 
                           pd.np.where(nintendo_df.Name.str.contains('Animal Crossing'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Another Code'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Art Academy'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Balloon Fight'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Big Brain Academy'), 'Y', 
                           pd.np.where(nintendo_df.Name.str.contains('Brain Age'), 'Y', 
                           pd.np.where(nintendo_df.Name.str.contains('Card Hero'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Chibi-Robo!'), 'Y',   
                           pd.np.where(nintendo_df.Name.str.contains('Clubhouse Games'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Custom Robo'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Daigasso! Band Brothers'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Donkey Kong'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Earthbound | Mother'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Excitebike'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Famicom Mini: Famicom Tantei Club'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Fire Emblem'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Fossil Fighters'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('F-1 Race'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('F-Zero'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Golden Sun'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Hyrule Warriors'), 'Y',            
                           #'Hyrule Warriors' is under 'The Legend of Zelda' franchise
                           pd.np.where(nintendo_df.Name.str.contains('Kid Icarus'), 'Y', 
                           pd.np.where(nintendo_df.Name.str.contains('Kirby'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Kururin'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('The Legendary Starfy'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('The Legend of Zelda'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Luigi'), 'Y',
                           #'Luigi' is under 'Mario' franchise
                           pd.np.where(nintendo_df.Name.str.contains('Magical Starsign'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Magnetica'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Mario'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Master of Illusion'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Metroid'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('NES Remix'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Paper Mario'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Picross'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Pikim'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Pilotwings'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Pokemon'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Pokémon'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Pikachu'), 'Y',             
                           pd.np.where(nintendo_df.Name.str.contains('PokePark'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Platinum Version'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Emerald Version'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Crystal Version'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Trading Card Game'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Stadium 2'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Colosseum'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Mystery Dungeon'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Squirtle'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Blastoise'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Johto Photo Finish'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('For Ho-Oh the Bells Toll!'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Polarium'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Puzzle League'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Rhythm Heaven'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Shaberu!'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Sin and Punishment'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Splatoon'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Star Fox'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Steel Diver'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Style Savvy'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Super Smash Bros.'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Tingle'), 'Y',             
                           #'Tingle' is under 'The Legend of Zelda' franchise            
                           pd.np.where(nintendo_df.Name.str.contains('Tomodachi'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Wario'), 'Y',            
                           #'Wario' is under 'Mario' franchise            
                           pd.np.where(nintendo_df.Name.str.contains('Advance Wars'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Famicon Wars'), 'Y',            
                           #Both belong to the 'Wars' franchise
                           pd.np.where(nintendo_df.Name.str.contains('Wave Race'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Wii'), 'Y',
                           #To take note of games under other franchise that's released for Wii
                           pd.np.where(nintendo_df.Name.str.contains('Xenoblade Chronicles'), 'Y',
                           pd.np.where(nintendo_df.Name.str.contains('Yakuman'), 'Y',            
                           pd.np.where(nintendo_df.Name.str.contains('Yoshi'), 'Y', 'N'
                           )))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))
                           #'Yoshi' is under 'Mario' franchise
# Out:
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_18919/2906610044.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   nintendo_df['Franchise'] = pd.np.where(nintendo_df.Name.str.contains('1080'), 'Y',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_18919/2906610044.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(nintendo_df.Name.str.contains('Animal Crossing'), 'Y',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_18919/2906610044.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(nintendo_df.Name.str.contains('Another Code'), 'Y',
# ...

# %%
nintendo_df['Franchise Name'] = pd.np.where(nintendo_df.Name.str.contains('1080'), '1080°', 
                                pd.np.where(nintendo_df.Name.str.contains('Animal Crossing'), 'Animal Crossing',
                                pd.np.where(nintendo_df.Name.str.contains('Another Code'), 'Another Code',
                                pd.np.where(nintendo_df.Name.str.contains('Art Academy'), 'Art Academy',
                                pd.np.where(nintendo_df.Name.str.contains('Balloon Fight'), 'Balloon Fight',
                                pd.np.where(nintendo_df.Name.str.contains('Big Brain Academy'), 'Big Brain Academy', 
                                pd.np.where(nintendo_df.Name.str.contains('Brain Age'), 'Brain Age', 
                                pd.np.where(nintendo_df.Name.str.contains('Card Hero'), 'Card Hero',
                                pd.np.where(nintendo_df.Name.str.contains('Chibi-Robo!'), 'Chibi-Robo!',   
                                pd.np.where(nintendo_df.Name.str.contains('Clubhouse Games'), 'Clubhouse Games',            
                                pd.np.where(nintendo_df.Name.str.contains('Custom Robo'), 'Custom Robo',            
                                pd.np.where(nintendo_df.Name.str.contains('Daigasso! Band Brothers'), 'Daigasso! Band Brothers',            
                                pd.np.where(nintendo_df.Name.str.contains('Donkey Kong'), 'Donkey Kong',            
                                pd.np.where(nintendo_df.Name.str.contains('Earthbound | Mother'), 'Mother',
                                pd.np.where(nintendo_df.Name.str.contains('Excitebike'), 'Excite',
                                pd.np.where(nintendo_df.Name.str.contains('Famicom Mini: Famicom Tantei Club'), 'Famicom Detective Club',
                                pd.np.where(nintendo_df.Name.str.contains('Fire Emblem'), 'Fire Emblem',
                                pd.np.where(nintendo_df.Name.str.contains('Fossil Fighters'), 'Fossil Fighters',
                                pd.np.where(nintendo_df.Name.str.contains('F-1 Race'), 'F-1 Race',
                                pd.np.where(nintendo_df.Name.str.contains('F-Zero'), 'F-Zero',
                                pd.np.where(nintendo_df.Name.str.contains('Golden Sun'), 'Golden Sun',            
                                pd.np.where(nintendo_df.Name.str.contains('Hyrule Warriors'), 'The Legend of Zelda',            
                                #'Hyrule Warriors' is under 'The Legend of Zelda' franchise
                                pd.np.where(nintendo_df.Name.str.contains('Kid Icarus'), 'Kid Icarus', 
                                pd.np.where(nintendo_df.Name.str.contains('Kirby'), 'Kirby',            
                                pd.np.where(nintendo_df.Name.str.contains('Kururin'), 'Kururin',            
                                pd.np.where(nintendo_df.Name.str.contains('The Legendary Starfy'), 'The Legendary Starfy',            
                                pd.np.where(nintendo_df.Name.str.contains('The Legend of Zelda'), 'The Legend of Zelda',
                                pd.np.where(nintendo_df.Name.str.contains('Luigi'), 'Mario',
                                #'Luigi' is under 'Mario' franchise
                                pd.np.where(nintendo_df.Name.str.contains('Magical Starsign'), 'Magical Starsign',
                                pd.np.where(nintendo_df.Name.str.contains('Magnetica'), 'Magnetica',
                                pd.np.where(nintendo_df.Name.str.contains('Mario'), 'Mario',
                                pd.np.where(nintendo_df.Name.str.contains('Master of Illusion'), 'Master of Illusion',
                                pd.np.where(nintendo_df.Name.str.contains('Metroid'), 'Metroid',            
                                pd.np.where(nintendo_df.Name.str.contains('NES Remix'), 'NES Remix',            
                                pd.np.where(nintendo_df.Name.str.contains('Paper Mario'), 'Mario',            
                                pd.np.where(nintendo_df.Name.str.contains('Picross'), 'Picross',            
                                pd.np.where(nintendo_df.Name.str.contains('Pikim'), 'Pikim',            
                                pd.np.where(nintendo_df.Name.str.contains('Pilotwings'), 'Pilotwings',            
                                pd.np.where(nintendo_df.Name.str.contains('Pokemon'), 'Pokémon',
                                pd.np.where(nintendo_df.Name.str.contains('Pokémon'), 'Pokémon',           
                                pd.np.where(nintendo_df.Name.str.contains('PokePark'), 'Pokémon',            
                                pd.np.where(nintendo_df.Name.str.contains('Polarium'), 'Polarium',
                                pd.np.where(nintendo_df.Name.str.contains('Puzzle League'), 'Puzzle League',
                                pd.np.where(nintendo_df.Name.str.contains('Rhythm Heaven'), 'Rhythm Heaven',
                                pd.np.where(nintendo_df.Name.str.contains('Shaberu!'), 'Shaberu! DS Oryouri NAVI',            
                                pd.np.where(nintendo_df.Name.str.contains('Sin and Punishment'), 'Sin and Punishment',            
                                pd.np.where(nintendo_df.Name.str.contains('Splatoon'), 'Splatoon',
                                pd.np.where(nintendo_df.Name.str.contains('Star Fox'), 'Star Fox',
                                pd.np.where(nintendo_df.Name.str.contains('Steel Diver'), 'Steel Diver',
                                pd.np.where(nintendo_df.Name.str.contains('Style Savvy'), 'Style Savvy',
                                pd.np.where(nintendo_df.Name.str.contains('Super Smash Bros.'), 'Super Smash Bros.',            
                                pd.np.where(nintendo_df.Name.str.contains('Tingle'), 'The Legend of Zelda',             
                                #'Tingle' is under 'The Legend of Zelda' franchise            
                                pd.np.where(nintendo_df.Name.str.contains('Tomodachi'), 'Tomodachi',
                                pd.np.where(nintendo_df.Name.str.contains('Wario'), 'Mario',            
                                #'Wario' is under 'Mario' franchise            
                                pd.np.where(nintendo_df.Name.str.contains('Advance Wars'), 'Wars',            
                                pd.np.where(nintendo_df.Name.str.contains('Famicon Wars'), 'Wars',            
                                #Both belong to the 'Wars' franchise
                                pd.np.where(nintendo_df.Name.str.contains('Wave Race'), 'Wave Race',            
                                pd.np.where(nintendo_df.Name.str.contains('Wii'), 'Wii',
                                #To take note of games under other franchise that's released for Wii
                                pd.np.where(nintendo_df.Name.str.contains('Xenoblade Chronicles'), 'Xenoblade Chronicles',
                                pd.np.where(nintendo_df.Name.str.contains('Yakuman'), 'Yakuman',            
                                pd.np.where(nintendo_df.Name.str.contains('Yoshi'), 'Mario', 'N.A.')))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))
                                #'Yoshi' is under 'Mario' franchise
# Out:
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_18919/1827888261.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   nintendo_df['Franchise Name'] = pd.np.where(nintendo_df.Name.str.contains('1080'), '1080°',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_18919/1827888261.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(nintendo_df.Name.str.contains('Animal Crossing'), 'Animal Crossing',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_18919/1827888261.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(nintendo_df.Name.str.contains('Another Code'), 'Another Code',
# ...

# %%
#Updating franchise name for those with overlapping substrings
nintendo_df.loc[nintendo_df['Name'].str.contains('Pikachu'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Platinum Version'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Emerald Version'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Crystal Version'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Trading Card Game'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Stadium 2'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Colosseum'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Mystery Dungeon'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Squirtle'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Blastoise'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('Johto Photo Finish'), 'Franchise Name'] = 'Pokémon'
nintendo_df.loc[nintendo_df['Name'].str.contains('For Ho-Oh the Bells Toll!'), 'Franchise Name'] = 'Pokémon'
# Out:
# /Users/jojotan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
#nintendo_df.to_csv('Nintendo.csv', index=False)

# %%
ntd_genre = nintendo_df['Genre'].value_counts()
ntd_genre
# Out:
# Platform        113
# Role-Playing    107
# Misc             99
# Action           80
# Puzzle           79
# Sports           56
# Racing           37
# Adventure        35
# Strategy         32
# Simulation       30
# Shooter          25
# Fighting         18
# Name: Genre, dtype: int64

# %%
inferno12 = ['#0e092b', '#2d0b59', '#4f0d6c', '#6d186e', '#8d2369', '#ad305d', 
             '#c83f4b', '#e15635', '#f2741c', '#fb9606', '#fbbc21', '#f3e35a']
labels = ['Platform', 'Role-Playing', 'Misc', 'Action', 'Puzzle', 'Sports',
          'Racing', 'Adventure', 'Strategy', 'Simulation', 'Shooter', 'Fighting']

fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(ntd_genre,
        colors = inferno12,
        labels = labels,
        autopct='%1.1f%%')
circle = plt.Circle( (0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Game Genre Distribution - Nintendo', loc = 'center', fontsize = 20)
plt.show()

# %%
nintendo_df.head(10)
#Best-selling games for Nintendo
# Out:
#    Rank                       Name Platform  Year         Genre  \
# 0     1                 Wii Sports      Wii  2006        Sports
# 1     2          Super Mario Bros.      NES  1985      Platform
# 2     3             Mario Kart Wii      Wii  2008        Racing
# 3     4          Wii Sports Resort      Wii  2009        Sports
# 4     5   Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# 5     6                     Tetris       GB  1989        Puzzle
# 6     7      New Super Mario Bros.       DS  2006      Platform
# 7     8                   Wii Play      Wii  2006          Misc
# 8     9  New Super Mario Bros. Wii      Wii  2009      Platform
# 9    10                  Duck Hunt      NES  1984       Shooter
#
#   Main Publisher Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0       Nintendo  Nintendo     41.49     29.02      3.77         8.46
# 1       Nintendo  Nintendo     29.08      3.58      6.81         0.77
# ...

# %%
nintendo_top_selling = pd.pivot_table(nintendo_df,
                                      index = ["Name", "Franchise Name", "Genre"],
                                      values=["Global_Sales"],
                                      aggfunc=[np.sum])
nintendo_top_selling = nintendo_top_selling.reset_index()
nintendo_top_selling = nintendo_top_selling.droplevel(1, axis = 1)
nintendo_top_selling.columns = ['Name', 'Franchise Name', 'Genre', 'Total Global Sales']
nintendo_top_selling.sort_values(by = ['Total Global Sales'],
                                 ascending = False,
                                 inplace = True)

nintendo_top_selling.head(10)
# Out:
#                           Name Franchise Name         Genre  \
# 650                 Wii Sports            Wii        Sports
# 539          Super Mario Bros.          Mario      Platform
# 582                     Tetris           N.A.        Puzzle
# 309             Mario Kart Wii          Mario        Racing
# 652          Wii Sports Resort            Wii        Sports
# 454   Pokemon Red/Pokemon Blue        Pokémon  Role-Playing
# 387      New Super Mario Bros.          Mario      Platform
# 648                   Wii Play            Wii          Misc
# 390  New Super Mario Bros. Wii          Mario      Platform
# 123                  Duck Hunt           N.A.       Shooter
#
#      Total Global Sales
# 650               82.74
# 539               45.31
# 582               35.84
# 309               35.82
# 652               33.00
# 454               31.37
# 387               30.01
# 648               29.02
# 390               28.62
# 123               28.31

# %%
sns.set(font_scale = 1)
sns.barplot(data = nintendo_df, 
            x = 'Genre', 
            y = 'Global_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre Globally - Nintendo", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre Globally - Nintendo')

# %%
platform_games = nintendo_df[nintendo_df['Genre'] == 'Platform']
platform_games.head(10)
# Out:
#     Rank                       Name Platform  Year     Genre Main Publisher  \
# 1      2          Super Mario Bros.      NES  1985  Platform       Nintendo
# 6      7      New Super Mario Bros.       DS  2006  Platform       Nintendo
# 8      9  New Super Mario Bros. Wii      Wii  2009  Platform       Nintendo
# 18    19          Super Mario World     SNES  1990  Platform       Nintendo
# 21    22           Super Mario Land       GB  1989  Platform       Nintendo
# 22    23        Super Mario Bros. 3      NES  1988  Platform       Nintendo
# 46    47             Super Mario 64      N64  1996  Platform       Nintendo
# 48    49         Super Mario Galaxy      Wii  2007  Platform       Nintendo
# 53    54        Super Mario 3D Land      3DS  2011  Platform       Nintendo
# 57    58      Super Mario All-Stars     SNES  1993  Platform       Nintendo
#
#    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# ...

# %%
roleplaying_games = nintendo_df[nintendo_df['Genre'] == 'Role-Playing']
roleplaying_games.head(10)
# Out:
#     Rank                                       Name Platform  Year  \
# 4      5                   Pokemon Red/Pokemon Blue       GB  1996
# 12    13                Pokemon Gold/Pokemon Silver       GB  1999
# 20    21              Pokemon Diamond/Pokemon Pearl       DS  2006
# 25    26              Pokemon Ruby/Pokemon Sapphire      GBA  2002
# 26    27                Pokemon Black/Pokemon White       DS  2010
# 30    31   Pok√©mon Yellow: Special Pikachu Edition       GB  1998
# 32    33                        Pokemon X/Pokemon Y      3DS  2013
# 49    50  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2014
# 58    59          Pokemon FireRed/Pokemon LeafGreen      GBA  2004
# 81    82            Pokemon Black 2/Pokemon White 2       DS  2012
#
#            Genre Main Publisher Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 4   Role-Playing       Nintendo  Nintendo     11.27      8.89     10.22
# 12  Role-Playing       Nintendo  Nintendo      9.00      6.18      7.20
# ...

# %% [markdown]
# The best-selling genre goes to 'platform' which constitutes to the most of the entire mix, followed closely by 'role-playing'. This could largely be due to most of the games under the genre being part of the company's successful franchises, notably the Mario franchise.
#
# The trend is uniform in all regions, except in Japan where the sale of role-playing games is on par with platform games. This could also be the possible driver for role-playing games to be the second best-selling genre globally for Nintendo. The high amount of sales could also be due to having games under another successful franchise of the company's, i.e. Pokémon, as shown in the table above. We can also surmise from the sales figure that the franchise is more popular in Japan than the other regions, given that the top 10 platform games sales fall under the franchise and the sales figures are almost on par with that of North America's - a pretty impressive feat given that the total population in North America is so much higher than that of Japan's.

# %%
sns.barplot(data = nintendo_df, 
            x = 'Genre', 
            y = 'NA_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in North America - Nintendo", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in North America - Nintendo')

# %%
sns.barplot(data = nintendo_df, 
            x = 'Genre', 
            y = 'EU_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Europe - Nintendo", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Europe - Nintendo')

# %%
sns.barplot(data = nintendo_df, 
            x = 'Genre', 
            y = 'JP_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Japan - Nintendo", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Japan - Nintendo')

# %%
sns.barplot(data = nintendo_df, 
            x = 'Genre', 
            y = 'Other_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Other Regions - Nintendo", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Other Regions - Nintendo')

# %%
#Why does Nintendo sell so much more compared to others? Cuz they invent the devices as well?
fig, ax = plt.subplots(figsize=(50, 25))
sns.set(font_scale = 3)
sns.lineplot(data = nintendo_df, 
             x = 'Year', 
             y = 'Global_Sales', 
             linewidth = 5, 
             color = '#57106e',
             estimator = sum,
             
             ci = None).set_title('Global Sales Across the Years - Nintendo', fontdict = {'size': 45})
# Out:
# Text(0.5, 1.0, 'Global Sales Across the Years - Nintendo')

# %%
print('Earliest Year Recorded:', nintendo_df.Year.min())
print('Latest Year Recorded:', nintendo_df.Year.max())
# Out:
# Earliest Year Recorded: 1983
# Latest Year Recorded: 2016

# %%
nintendo_df2 = nintendo_df.drop(['Rank', 'Global_Sales', 'Publisher', 'Franchise', 'Franchise Name'], axis = 1)
nintendo_df2 = nintendo_df2.melt(id_vars = ['Name', 'Platform', 'Year', 'Genre', 'Main Publisher'], 
                                 var_name = 'Region',
                                 value_name = 'Total Sales')
nintendo_df2.loc[nintendo_df2['Region'] == 'NA_Sales', 'Region'] = 'NA'
nintendo_df2.loc[nintendo_df2['Region'] == 'EU_Sales', 'Region'] = 'EU'
nintendo_df2.loc[nintendo_df2['Region'] == 'JP_Sales', 'Region'] = 'JP'
nintendo_df2.loc[nintendo_df2['Region'] == 'Other_Sales', 'Region'] = 'Other'

# %%
fig, ax = plt.subplots(figsize=(50, 25))
sns.set(font_scale = 3)
sns.lineplot(data = nintendo_df2, 
             x = 'Year', 
             y = 'Total Sales',
             hue = 'Region',
             linewidth = 5, 
             palette = sns.color_palette('plasma', 4),
             estimator = sum,
             ci = None).set_title('Sales by Region Across the Years - Nintendo', fontdict = {'size': 45})
# Out:
# Text(0.5, 1.0, 'Sales by Region Across the Years - Nintendo')

# %%
sales_figures = pd.pivot_table(nintendo_df,
                               index = ['Year'],
                               values = ['Global_Sales'],
                               aggfunc = np.sum)
sales_figures = sales_figures.reset_index()
sales_figures.sort_values(by = ['Global_Sales'], 
                              ascending = False,
                              inplace = True)

sales_figures.head()
# Out:
#     Year  Global_Sales
# 23  2006        205.67
# 26  2009        128.67
# 22  2005        127.52
# 24  2007        104.20
# 25  2008         91.93

# %%
ntd_05_09 = nintendo_df[nintendo_df.Year.isin(['2005', '2006', '2007', '2008', '2009'])]

ntd_05_09 = pd.pivot_table(ntd_05_09,
                               index = ["Name", 'Franchise Name', "Year", "Platform"],
                           values=["Global_Sales"],
                           aggfunc=[np.sum])
ntd_05_09 = ntd_05_09.reset_index()
ntd_05_09 = ntd_05_09.droplevel(1, axis = 1)
ntd_05_09.columns = ['Name', 'Franchise Name', 'Year', 'Platform', 'Total Global Sales']
ntd_05_09.sort_values(by = ['Total Global Sales'], 
                              ascending = False,
                              inplace = True)

ntd_05_09.head(10)
# Out:
#                           Name Franchise Name  Year Platform  \
# 200                 Wii Sports            Wii  2006      Wii
# 91              Mario Kart Wii          Mario  2008      Wii
# 201          Wii Sports Resort            Wii  2009      Wii
# 122      New Super Mario Bros.          Mario  2006       DS
# 199                   Wii Play            Wii  2006      Wii
# 123  New Super Mario Bros. Wii          Mario  2009      Wii
# 125                 Nintendogs           N.A.  2005       DS
# 90               Mario Kart DS          Mario  2005       DS
# 196                    Wii Fit            Wii  2007      Wii
# 197               Wii Fit Plus            Wii  2009      Wii
#
#      Total Global Sales
# 200               82.74
# 91                35.82
# 201               33.00
# 122               30.01
# 199               29.02
# 123               28.62
# 125               24.76
# 90                23.42
# 196               22.72
# 197               22.00

# %%
ntd_05_09['Year'].value_counts()
# Out:
# 2006    54
# 2005    46
# 2007    43
# 2008    34
# 2009    32
# Name: Year, dtype: int64

# %%
franchise_sales_05_09 = ntd_05_09[ntd_05_09['Franchise Name'] != 'N.A.']
franchise_sales_05_09 = pd.pivot_table(franchise_sales_05_09,
                                       index = ['Franchise Name'],
                                       values = ['Total Global Sales'],
                                       aggfunc = np.sum)
franchise_sales_05_09 = franchise_sales_05_09.reset_index()
franchise_sales_05_09.sort_values(by = ['Total Global Sales'],
                                  ascending = False,
                                  inplace = True)
franchise_sales_05_09.head(10)
# Out:
#          Franchise Name  Total Global Sales
# 29                  Wii              192.75
# 14                Mario              179.17
# 18              Pokémon               59.02
# 3             Brain Age               35.52
# 26  The Legend of Zelda               17.81
# 0       Animal Crossing               16.95
# 25    Super Smash Bros.               13.04
# 2     Big Brain Academy               10.49
# 11                Kirby                5.65
# 8           Donkey Kong                3.79

# %% [markdown]
# Nintendo's highest sales recorded between 1983 to 2016 were from 2005 to 2009, with its peak in 2006. This was mainly due to the release of Wii in the same year; this has always been an advantage for Nintendo - with every release of a new console, consumers will definitely have to purchase games published by them in order to enjoy their new gadgets. They will also have to constantly publish new games for the platform subsequently to retain consumers' interest. We can see this from how the number of games released in 2006 was the highest when the console was released, followed by 2005 (a year after the DS console was released) and that the Wii franchise held the highest global sales during this five-year period - this doesn't include games released for the platform under other franchises.
#
# The steady fall and decline in game releases subsequently from 2007 to 2009 can be attributed to the recession which lasted till mid-2009, seemingly explaining the pick up in sales from 2008.

# %% [markdown]
# #### Franchise Sales

# %%
franchise_release = nintendo_df['Franchise'].value_counts()
franchise_release
# Out:
# Y    407
# N    304
# Name: Franchise, dtype: int64

# %%
whew = ['#ae7181', '#8eab12'] #mauve and pea green
labels = ['Franchise', 'Non-Franchise']
fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(franchise_release,
        colors = whew,
        labels = labels,
        autopct='%1.1f%%')
plt.title('Game Release Distribution - Nintendo', loc = 'center', fontsize = 20)
plt.show()

# %%
franchise_sales = pd.pivot_table(nintendo_df,
                                 index = ['Franchise'],
                                 values = ['Global_Sales'],
                                 aggfunc = np.sum)
franchise_sales = franchise_sales.reset_index()
franchise_sales.sort_values(by = ['Global_Sales'],
                           ascending = False,
                           inplace = True)
franchise_sales
# Out:
#   Franchise  Global_Sales
# 1         Y       1434.61
# 0         N        354.36

# %%
whew = ['#ae7181', '#8eab12'] #mauve and pea green
amounts = [1434.61, 354.36]
labels = ['Franchise', 'Non-Franchise']
fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(amounts,
        colors = whew,
        labels = labels,
        autopct='%1.1f%%')
plt.title('Game Sales Contribution - Nintendo', loc = 'center', fontsize = 20)
plt.show()

# %%
franchise_sales = nintendo_df[nintendo_df['Franchise'] == 'Y']
top_franchise = pd.pivot_table(franchise_sales,
                               index = ['Franchise Name'],
                               values = ['Global_Sales'],
                               aggfunc = np.sum)
top_franchise = top_franchise.reset_index()
top_franchise.sort_values(by = ['Global_Sales'],
                          ascending = False,
                          inplace = True)
top_franchise.head(10)
# Out:
#          Franchise Name  Global_Sales
# 25                Mario        564.82
# 31              Pokémon        253.90
# 47                  Wii        206.46
# 42  The Legend of Zelda         79.60
# 12          Donkey Kong         64.44
# 41    Super Smash Bros.         38.13
# 21                Kirby         37.28
# 6             Brain Age         35.61
# 1       Animal Crossing         32.59
# 27              Metroid         17.96

# %%
twilight_r = ['#d2b7a5', '#c48065', '#a94950', '#7b2150', '#41123d', 
              '#3e1150', '#5b3196', '#6068b6', '#759ac1', '#adc3cd']
sales = [564.82, 253.90, 206.46, 79.60, 64.44, 38.13, 37.28, 35.61, 32.59, 17.96]
labels = ['Mario', 'Pokémon', 'Wii', 'The Legend of Zelda', 'Donkey Kong',
          'Super Smash Bros.', 'Kirby', 'Brain Age', 'Animal Crossing', 'Metroid']

fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(sales,
        colors = twilight_r,
        labels = labels,
        autopct='%1.1f%%')
circle = plt.Circle( (0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Top 10 Franchise Sales - Nintendo', loc = 'center', fontsize = 20)
plt.show()

# %% [markdown]
# While the difference in franchise and non-franchise releases is relatively small, Nintendo's main sales contributors are the games released under their franchises, with Mario taking the biggest lead. This makes it all the more impressive regarding the longevity of Mario's popularity, given that its first game was released in 1985 and also highlighted the success of the Wii franchise (which has been discontinued since 2013) with the high amount of sales it had raked up despite being only released in 2006.

# %% [markdown]
# #### Platform Sales

# %%
platform_sales_pvt = pd.pivot_table(nintendo_df,
                                    index = ['Platform'],
                                    values = ['Global_Sales'],
                                    aggfunc = np.sum)
platform_sales_df = platform_sales_pvt.reset_index()
platform_sales_df.sort_values(by = ['Global_Sales'], 
                              ascending = False,
                              inplace = True)
platform_sales_df
# Out:
#   Platform  Global_Sales
# 8      Wii        391.34
# 1       DS        349.81
# 2       GB        230.09
# 6      NES        183.97
# 0      3DS        156.47
# 5      N64        129.95
# 3      GBA        113.21
# 7     SNES         96.84
# 4       GC         79.39
# 9     WiiU         57.90

# %%
sns.set(font_scale = 1)
sns.barplot(data = platform_sales_df, 
            x = 'Global_Sales', 
            y = 'Platform',
            orient = 'h',
            palette = sns.color_palette('copper_r', n_colors = 10),
            estimator = sum,
            ci = None).set_title("All-Time Sales by Platform - Nintendo", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'All-Time Sales by Platform - Nintendo')

# %% [markdown]
# Nintendo's sales are generally monopolised by Wii and DS games and it does not seem to publish any games for platforms outside of its own consoles - unlike Sony (PlayStation) and Microsoft (Xbox), albeit negligible sales figures. It is, however, remarkable for Wii sales to surpass that of DS, given that the latter had a two-year head start in the market - though it is also very dependable on the types of games released for each platform and the target audience the games hope to reach. Data only reaches 2016, thus excluding sales by Switch, which was first released in 2017.

# %%
sony_df = clean_df[clean_df['Main Publisher'] == 'Sony']
ms_df = clean_df[clean_df['Main Publisher'] == 'Microsoft Game Studios']

# %%
sony_platform_sales = pd.pivot_table(sony_df,
                                     index = ['Platform'],
                                     values = ['Global_Sales'],
                                     aggfunc = np.sum)
sony_platform_sales = sony_platform_sales.reset_index()
sony_platform_sales.sort_values(by = ['Global_Sales'], 
                              ascending = False,
                              inplace = True)
sony_platform_sales
# Out:
#   Platform  Global_Sales
# 2       PS        207.61
# 3      PS2        180.61
# 4      PS3        154.10
# 6      PSP         54.25
# 5      PS4         38.88
# 7      PSV         14.61
# 0      GBA          0.93
# 1       PC          0.30

# %%
sns.barplot(data = sony_platform_sales, 
            x = 'Global_Sales', 
            y = 'Platform',
            orient = 'h',
            palette = sns.color_palette('Wistia', n_colors = 8),
            estimator = sum,
            ci = None).set_title("All-Time Sales by Platform - Sony", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'All-Time Sales by Platform - Sony')

# %%
ms_platform_sales = pd.pivot_table(ms_df, 
                                   index = ['Platform'],
                                   values = ['Global_Sales'],
                                   aggfunc = np.sum)
ms_platform_sales = ms_platform_sales.reset_index()
ms_platform_sales.sort_values(by = ['Global_Sales'], 
                              ascending = False,
                              inplace = True)
ms_platform_sales
# Out:
#   Platform  Global_Sales
# 2     X360        165.16
# 3       XB         46.97
# 4     XOne         25.40
# 0       PC          7.83
# 1     WiiU          0.43

# %%
sns.barplot(data = ms_platform_sales, 
            x = 'Global_Sales', 
            y = 'Platform',
            orient = 'h',
            palette = sns.color_palette('YlGnBu', n_colors = 5),
            estimator = sum,
            ci = None).set_title("All-Time Sales by Platform - Microsoft", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'All-Time Sales by Platform - Microsoft')
