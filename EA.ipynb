# %% [markdown]
# # Electronic Arts

# %% [markdown]
# Founded in 1982 by Apple employee Trip Hawkins, Electronic Arts Inc. (EA) is an American video game company headquartered in Redwood City, California. The company was a pioneer of the early home computer game industry and published numerous games and some productivity software for personal computers, all of which were developed by external individuals or groups until 1987's Skate or Die!.
#
# EA currently develops and publishes games of established franchises, including Battlefield, Need for Speed, The Sims, Medal of Honor, Command & Conquer, Dead Space, Mass Effect, Dragon Age, Army of Two, Apex Legends, and Star Wars, as well as the EA Sports titles FIFA, Madden NFL, NBA Live, NHL, and EA Sports UFC.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
clean_df = pd.read_csv("/Users/jojotan/Documents/Portfolio/Video_Games/clean_vgsales.csv")
clean_df = clean_df.astype({"Year": int})

# %%
ea_df = clean_df[clean_df['Main Publisher'] == 'Electronic Arts']

# %%
ea_df['Franchise'] = pd.np.where(ea_df.Name.str.contains('Army of Two'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Battlefield'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Burnout'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Command & Conquer'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Crusader: No Remorse'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Crysis'), 'Y', 
                     pd.np.where(ea_df.Name.str.contains('Dead Space'), 'Y', 
                     pd.np.where(ea_df.Name.str.contains('Dragon Age'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Dungeon Keeper'), 'Y',   
                     pd.np.where(ea_df.Name.str.contains('EA Sports Active'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('EA Sports UFC'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('F1'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('FIFA'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('FIFA Manager'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('FIFA Street'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('FIFA World Cup'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Fight Night'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Grand Slam Tennis'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Hasbro Family Game Night'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Knockout Kings'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Madden NFL'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Magic Carpet'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Mass Effect'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Medal of Honor'), 'Y',
                     pd.np.where(ea_df.Name.str.contains("Mirror's Edge"), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Monopoly'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('MVP Baseball'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('MySims'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('NBA Live'), 'Y',           
                     pd.np.where(ea_df.Name.str.contains('NBA Street'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('NCAA Basketball'), 'Y',           
                     pd.np.where(ea_df.Name.str.contains('NCAA Football'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Need for Speed'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Nerf N-Strike'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('NFL Street'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('NHL'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('PGA Tour'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Plants vs. Zombies'), 'Y',           
                     pd.np.where(ea_df.Name.str.contains('Populous'), 'Y',           
                     pd.np.where(ea_df.Name.str.contains('Road Rash'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('Sim'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('SimCity'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('The Simpsons'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('The Sims'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Skate'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('SSX'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('Star Wars Battlefront'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('Star Wars: The Old Republic'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Syndicate'), 'Y',
                     pd.np.where(ea_df.Name.str.contains('Theme Park'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('Titanfall'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('Triple Play'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('UEFA Champions League'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('UEFA Euro'), 'Y',            
                     pd.np.where(ea_df.Name.str.contains('Wing Commander'), 'Y', 'N'
                                )))))))))))))))))))))))))))))))))))))))))))))))))))))))
# Out:
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_8349/36284214.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   ea_df['Franchise'] = pd.np.where(ea_df.Name.str.contains('Army of Two'), 'Y',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_8349/36284214.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(ea_df.Name.str.contains('Battlefield'), 'Y',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_8349/36284214.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(ea_df.Name.str.contains('Burnout'), 'Y',
# ...

# %%
ea_df['Franchise Name'] = pd.np.where(ea_df.Name.str.contains('Army of Two'), 'Army of Two',
                          pd.np.where(ea_df.Name.str.contains('Battlefield'), 'Battlefield',
                          pd.np.where(ea_df.Name.str.contains('Burnout'), 'Burnout',
                          pd.np.where(ea_df.Name.str.contains('Command & Conquer'), 'Command & Conquer',
                          pd.np.where(ea_df.Name.str.contains('Crusader: No Remorse'), 'Crusader: No Remorse',
                          pd.np.where(ea_df.Name.str.contains('Crysis'), 'Crysis', 
                          pd.np.where(ea_df.Name.str.contains('Dead Space'), 'Dead Space', 
                          pd.np.where(ea_df.Name.str.contains('Dragon Age'), 'Dragon Age',
                          pd.np.where(ea_df.Name.str.contains('Dungeon Keeper'), 'Dungeon Keeper',   
                          pd.np.where(ea_df.Name.str.contains('EA Sports Active'), 'EA Sports Active',            
                          pd.np.where(ea_df.Name.str.contains('EA Sports UFC'), 'EA Sports UFC',            
                          pd.np.where(ea_df.Name.str.contains('F1'), 'F1',            
                          pd.np.where(ea_df.Name.str.contains('FIFA'), 'FIFA',            
                          pd.np.where(ea_df.Name.str.contains('FIFA Manager'), 'FIFA Manager',
                          pd.np.where(ea_df.Name.str.contains('FIFA Street'), 'FIFA Street',
                          pd.np.where(ea_df.Name.str.contains('FIFA World Cup'), 'FIFA World Cup',
                          pd.np.where(ea_df.Name.str.contains('Fight Night'), 'Fight Night',
                          pd.np.where(ea_df.Name.str.contains('Grand Slam Tennis'), 'Grand Slam Tennis',
                          pd.np.where(ea_df.Name.str.contains('Hasbro Family Game Night'), 'Hasbro Family Game Night',
                          pd.np.where(ea_df.Name.str.contains('Knockout Kings'), 'Knockout Kings',
                          pd.np.where(ea_df.Name.str.contains('Madden NFL'), 'Madden NFL',
                          pd.np.where(ea_df.Name.str.contains('Magic Carpet'), 'Magic Carpet',
                          pd.np.where(ea_df.Name.str.contains('Mass Effect'), 'Mass Effect',
                          pd.np.where(ea_df.Name.str.contains('Medal of Honor'), 'Medal of Honor',
                          pd.np.where(ea_df.Name.str.contains("Mirror's Edge"), "Mirror's Edge",
                          pd.np.where(ea_df.Name.str.contains('Monopoly'), 'Monopoly',
                          pd.np.where(ea_df.Name.str.contains('MVP Baseball'), 'MVP Baseball',
                          pd.np.where(ea_df.Name.str.contains('MySims'), 'MySims',
                          pd.np.where(ea_df.Name.str.contains('NBA Live'), 'NBA Live',           
                          pd.np.where(ea_df.Name.str.contains('NBA Street'), 'NBA Street',
                          pd.np.where(ea_df.Name.str.contains('NCAA Basketball'), 'NCAA Basketball',           
                          pd.np.where(ea_df.Name.str.contains('NCAA Football'), 'NCAA Football',
                          pd.np.where(ea_df.Name.str.contains('Need for Speed'), 'Need for Speed',
                          pd.np.where(ea_df.Name.str.contains('Nerf N-Strike'), 'Nerf N-Strike',
                          pd.np.where(ea_df.Name.str.contains('NFL Street'), 'NFL Street',
                          pd.np.where(ea_df.Name.str.contains('NHL'), 'NHL',
                          pd.np.where(ea_df.Name.str.contains('PGA Tour'), 'PGA Tour',
                          pd.np.where(ea_df.Name.str.contains('Plants vs. Zombies'), 'Plants vs. Zombies',           
                          pd.np.where(ea_df.Name.str.contains('Populous'), 'Populous',           
                          pd.np.where(ea_df.Name.str.contains('Road Rash'), 'Road Rash',            
                          pd.np.where(ea_df.Name.str.contains('Sim'), 'Sim',
                          pd.np.where(ea_df.Name.str.contains('SimCity'), 'SimCity',
                          pd.np.where(ea_df.Name.str.contains('The Simpsons'), 'The Simpsons',
                          pd.np.where(ea_df.Name.str.contains('The Sims'), 'The Sims',
                          pd.np.where(ea_df.Name.str.contains('Skate'), 'Skate',
                          pd.np.where(ea_df.Name.str.contains('SSX'), 'Y',            
                          pd.np.where(ea_df.Name.str.contains('Star Wars Battlefront'), 'Star Wars Battlefront',            
                          pd.np.where(ea_df.Name.str.contains('Star Wars: The Old Republic'), 'Star Wars: Knights of the Old Republic',
                          pd.np.where(ea_df.Name.str.contains('Syndicate'), 'Syndicate',
                          pd.np.where(ea_df.Name.str.contains('Theme Park'), 'Theme Park',            
                          pd.np.where(ea_df.Name.str.contains('Titanfall'), 'Titanfall',            
                          pd.np.where(ea_df.Name.str.contains('Triple Play'), 'Triple Play',            
                          pd.np.where(ea_df.Name.str.contains('UEFA Champions League'), 'UEFA Champions League',            
                          pd.np.where(ea_df.Name.str.contains('UEFA Euro'), 'UEFA Euro',            
                          pd.np.where(ea_df.Name.str.contains('Wing Commander'), 'Wing Commander', 'N.A.'
                                )))))))))))))))))))))))))))))))))))))))))))))))))))))))
# Out:
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_8349/2217954141.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   ea_df['Franchise Name'] = pd.np.where(ea_df.Name.str.contains('Army of Two'), 'Army of Two',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_8349/2217954141.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(ea_df.Name.str.contains('Battlefield'), 'Battlefield',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_8349/2217954141.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(ea_df.Name.str.contains('Burnout'), 'Burnout',
# ...

# %%
#Updating franchise name for those with overlapping substrings
ea_df.loc[ea_df['Name'].str.contains('FIFA Manager'), 'Franchise Name'] = 'FIFA Manager'
ea_df.loc[ea_df['Name'].str.contains('FIFA Street'), 'Franchise Name'] = 'FIFA Street'
ea_df.loc[ea_df['Name'].str.contains('FIFA World Cup'), 'Franchise Name'] = 'FIFA World Cup'
ea_df.loc[ea_df['Name'].str.contains('The Simpsons'), 'Franchise Name'] = 'The Simpsons'
ea_df.loc[ea_df['Name'].str.contains('The Sims'), 'Franchise Name'] = 'The Sims'
# Out:
# /Users/jojotan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
#ea_df.to_csv('EA.csv', index=False)

# %%
ea_genre = ea_df['Genre'].value_counts()
ea_genre
# Out:
# Sports          581
# Action          171
# Racing          159
# Shooter         140
# Simulation      119
# Misc             43
# Fighting         39
# Strategy         37
# Role-Playing     35
# Platform         16
# Adventure        13
# Puzzle            9
# Name: Genre, dtype: int64

# %%
inferno12 = ['#0e092b', '#2d0b59', '#4f0d6c', '#6d186e', '#8d2369', '#ad305d', 
             '#c83f4b', '#e15635', '#f2741c', '#fb9606', '#fbbc21', '#f3e35a']
labels = ['Sports', 'Action', 'Racing', 'Shooter', 'Simulation', 'Misc',
          'Fighting', 'Strategy', 'Role-Playing', 'Platform', 'Adventure', 'Puzzle']

fig, ax = plt.subplots(figsize=(20, 12))
plt.pie(ea_genre,
        colors = inferno12,
        labels = labels,
        autopct='%1.1f%%')
circle = plt.Circle( (0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Game Genre Distribution - Electronic Arts', loc = 'center', fontsize = 20)
plt.show()

# %%
ea_df.head(10)
#top 10 best-selling games for EA
# Out:
#      Rank                          Name Platform  Year       Genre  \
# 77     78                       FIFA 16      PS4  2015      Sports
# 82     83                FIFA Soccer 13      PS3  2012      Sports
# 83     84                    The Sims 3       PC  2009  Simulation
# 92     93  Star Wars Battlefront (2015)      PS4  2015     Shooter
# 99    100                 Battlefield 3     X360  2011     Shooter
# 103   104                 Battlefield 3      PS3  2011     Shooter
# 104   105    Need for Speed Underground      PS2  2003      Racing
# 112   113                       FIFA 14      PS3  2013      Sports
# 113   114  Need for Speed Underground 2      PS2  2004      Racing
# 114   115     Medal of Honor: Frontline      PS2  2002     Shooter
#
#       Main Publisher        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 77   Electronic Arts  Electronic Arts      1.11      6.06      0.06
# 82   Electronic Arts  Electronic Arts      1.06      5.05      0.13
# ...

# %% [markdown]
# Since the top 10 includes same game titles due to the different platforms that they are released on, we will use pivot table to consolidate and sum up the total global sales for each game instead.

# %%
ea_top_selling = pd.pivot_table(ea_df,
                                index = ["Name", "Franchise Name", "Genre"],
                                values=["Global_Sales"],
                                aggfunc=[np.sum])
ea_top_selling = ea_top_selling.reset_index()
ea_top_selling = ea_top_selling.droplevel(1, axis = 1)
ea_top_selling.columns = ['Name', 'Franchise Name', 'Genre', 'Total Global Sales']
ea_top_selling.sort_values(by = ['Total Global Sales'], 
                              ascending = False,
                              inplace = True)

ea_top_selling.head(10)
# Out:
#                             Name  Franchise Name       Genre  \
# 128                      FIFA 15            FIFA      Sports
# 25                 Battlefield 3     Battlefield     Shooter
# 127                      FIFA 14            FIFA      Sports
# 129                      FIFA 16            FIFA      Sports
# 144               FIFA Soccer 13            FIFA      Sports
# 534                   The Sims 3        The Sims  Simulation
# 412  Need for Speed: Most Wanted  Need for Speed      Racing
# 26                 Battlefield 4     Battlefield     Shooter
# 126                      FIFA 12            FIFA      Sports
# 143               FIFA Soccer 11            FIFA      Sports
#
#      Total Global Sales
# 128               19.02
# 25                17.36
# 127               17.14
# 129               16.44
# 144               16.16
# 534               15.45
# 412               14.08
# 26                14.03
# 126               13.15
# 143               12.56

# %%
sns.barplot(data = ea_df, 
            x = 'Genre', 
            y = 'Global_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre Globally - Electronic Arts", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre Globally - Electronic Arts')

# %% [markdown]
# EA seems to be largely focused on the 'Sports' genre as it is their most released genre and also their best-selling genre, with majority of the top 10 best-selling games being from it. The genre has a huge lead in all regions except in Japan where it's followed closely by the genres 'Shooter' and 'Role-Playing'. We can also see that the Japanese audience seems to be more receptive / open to other genres published by the company as compared to the other three.
#
# The high sales of the 'Sports' genre can be attributed to the numerous games released which are part of the company's successful franchises, namely FIFA. It is also brings in a steady stream of income given that the game is released annually.

# %%
sns.barplot(data = ea_df, 
            x = 'Genre', 
            y = 'NA_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in North America - Electronic Arts", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in North America - Electronic Arts')

# %%
sns.barplot(data = ea_df, 
            x = 'Genre', 
            y = 'EU_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Europe - Electronic Arts", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Europe - Electronic Arts')

# %%
sns.barplot(data = ea_df, 
            x = 'Genre', 
            y = 'JP_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Japan - Electronic Arts", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Japan - Electronic Arts')

# %%
sns.barplot(data = ea_df, 
            x = 'Genre', 
            y = 'Other_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Other Regions - Electronic Arts", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Other Regions - Electronic Arts')

# %%
fig, ax = plt.subplots(figsize=(50, 25))
sns.set(font_scale = 3)
sns.lineplot(data = ea_df, 
             x = 'Year', 
             y = 'Global_Sales', 
             linewidth = 5, 
             color = '#f98e09',
             estimator = sum,
             ci = None).set_title('Global Sales Across the Years - Electronic Arts', fontdict = {'size': 45})
# Out:
# Text(0.5, 1.0, 'Global Sales Across the Years - Electronic Arts')

# %%
print('Earliest Year Recorded:', ea_df.Year.min())
print('Latest Year Recorded:', ea_df.Year.max())
# Out:
# Earliest Year Recorded: 1992
# Latest Year Recorded: 2016

# %%
ea_df2 = ea_df.drop(['Rank', 'Global_Sales', 'Publisher'], axis = 1)
ea_df2 = ea_df2.melt(id_vars = ['Name', 'Platform', 'Year', 'Genre', 'Main Publisher', 'Franchise', 'Franchise Name'],
                     var_name = 'Region',
                     value_name = 'Total Sales')
ea_df2.loc[ea_df2['Region'] == 'NA_Sales', 'Region'] = 'NA'
ea_df2.loc[ea_df2['Region'] == 'EU_Sales', 'Region'] = 'EU'
ea_df2.loc[ea_df2['Region'] == 'JP_Sales', 'Region'] = 'JP'
ea_df2.loc[ea_df2['Region'] == 'Other_Sales', 'Region'] = 'Others'

# %%
fig, ax = plt.subplots(figsize=(50, 25))
sns.set(font_scale = 3)
sns.lineplot(data = ea_df2, 
             x = 'Year', 
             y = 'Total Sales',
             hue = 'Region',
             linewidth = 5, 
             palette = sns.color_palette('plasma', 4),
             estimator = sum,
             ci = None).set_title('Sales by Region Across the Years - Electronic Arts', fontdict = {'size': 45})
# Out:
# Text(0.5, 1.0, 'Sales by Region Across the Years - Electronic Arts')

# %%
ea_00_02 = ea_df[ea_df.Year.isin(['2000', '2001', '2002'])]

ea_00_02 = pd.pivot_table(ea_00_02,
                          index = ["Name", 'Franchise Name', "Year"],
                          values=["Global_Sales"],
                          aggfunc=[np.sum])
ea_00_02 = ea_00_02.reset_index()
ea_00_02 = ea_00_02.droplevel(1, axis = 1)
ea_00_02.columns = ['Name', 'Franchise', 'Year', 'Total Global Sales']
ea_00_02.sort_values(by = ['Total Global Sales'], 
                              ascending = False,
                              inplace = True)
ea_00_02['Year'].value_counts()
# Out:
# 2002    48
# 2000    27
# 2001    24
# Name: Year, dtype: int64

# %%
ea_00_02[ea_00_02['Year'] == 2002].head()
# Out:
#                                        Name       Franchise  Year  \
# 47                Medal of Honor: Frontline  Medal of Honor  2002
# 31  Harry Potter and the Chamber of Secrets            N.A.  2002
# 80    The Lord of the Rings: The Two Towers            N.A.  2002
# 46                          Madden NFL 2003      Madden NFL  2002
# 36                James Bond 007: Nightfire            N.A.  2002
#
#     Total Global Sales
# 47                8.91
# 31                7.64
# 80                6.65
# 46                5.89
# 36                4.93

# %% [markdown]
# Like Nintendo, EA's biggest market is the North American. The sharpest inclination on the graph was from 2000 - 2002, when EA published double the number of games in 2002 than it did the year before, with the top 3 best-selling games that year largely dominated by games from its popular franchises and games that were based on the popular films that were released in the same year (Harry Potter and The Lord of the Rings) - especially the latter whose sales rode off on the success of the films that were released first.
#
# The sharp inclination could also be due to the release of the PlayStation 2 in 2000; the console received widespread critical acclaim upon release and a total of over 4,000 game titles were released worldwide, with over 1.5 billion copies sold (source: Wikipedia). PS2 is also the best-selling platform for EA, further backing the possibility of its release being one of the drives behind the steep increase in global sales during the period.
#
# There was a gradual decline shortly before 2010 and we can surmise that to be due to the global economic downturn. On top of that, it could also be due to the shifting of the industry where it was slowly evolving from selling packaged goods to online distribution and via mobile devices.

# %% [markdown]
# #### Platform Sales

# %%
platform_sales = pd.pivot_table(ea_df,
                                index = ['Platform'],
                                values = ['Global_Sales'],
                                aggfunc = np.sum)
platform_sales = platform_sales.reset_index()
platform_sales.sort_values(by = ['Global_Sales'],
                           ascending = False,
                           inplace = True)

platform_sales
# Out:
#    Platform  Global_Sales
# 8       PS2        255.79
# 16     X360        181.04
# 9       PS3        168.86
# 7        PS         92.34
# 6        PC         71.44
# 14      Wii         63.75
# 17       XB         58.91
# 10      PS4         55.32
# 11      PSP         39.85
# 1        DS         33.15
# 18     XOne         29.34
# 4        GC         27.96
# 3       GBA         14.31
# 5       N64         13.49
# 12      PSV          3.91
# 0       3DS          2.72
# 2        GB          1.73
# 15     WiiU          1.28
# 13      SAT          0.08

# %%
sns.set(font_scale = 1)
sns.barplot(data = platform_sales, 
            x = 'Global_Sales', 
            y = 'Platform',
            orient = 'h',
            palette = sns.color_palette('copper_r', n_colors = 19),
            estimator = sum,
            ci = None).set_title("All-Time Sales by Platform - Electronic Arts", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'All-Time Sales by Platform - Electronic Arts')

# %% [markdown]
# #### Franchise Sales

# %%
franchise_release = ea_df['Franchise'].value_counts()
franchise_release
# Out:
# Y    934
# N    428
# Name: Franchise, dtype: int64

# %%
whew = ['#ae7181', '#8eab12'] #mauve and pea green
labels = ['Franchise', 'Non-Franchise']
fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(franchise_release,
        colors = whew,
        labels = labels,
        autopct='%1.1f%%')
plt.title('Game Release Distribution - Electronic Arts', loc = 'center', fontsize = 20)
plt.show()

# %%
franchise_sales = pd.pivot_table(ea_df,
                                index = ['Franchise'],
                                values = ['Global_Sales'],
                                aggfunc = np.sum)
franchise_sales = franchise_sales.reset_index()
franchise_sales.sort_values(by = ['Global_Sales'],
                           ascending = False,
                           inplace = True)
franchise_sales
# Out:
#   Franchise  Global_Sales
# 1         Y        890.75
# 0         N        224.52

# %%
whew = ['#ae7181', '#8eab12'] #mauve and pea green
amounts = [890.75, 224.52]
labels = ['Franchise', 'Non-Franchise']
fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(amounts,
        colors = whew,
        labels = labels,
        autopct='%1.1f%%')
plt.title('Game Sales Contribution - Electronic Arts', loc = 'center', fontsize = 20)
plt.show()

# %%
franchise_sales = ea_df[ea_df['Franchise'] == 'Y']
top_franchise = pd.pivot_table(franchise_sales,
                               index = ['Franchise Name'],
                               values = ['Global_Sales'],
                               aggfunc = np.sum)
top_franchise = top_franchise.reset_index()
top_franchise.sort_values(by = ['Global_Sales'],
                          ascending = False,
                          inplace = True)
top_franchise.head(10)
# Out:
#     Franchise Name  Global_Sales
# 12            FIFA        163.79
# 21      Madden NFL        122.65
# 34  Need for Speed         91.55
# 45        The Sims         65.29
# 1      Battlefield         47.25
# 24  Medal of Honor         37.77
# 28        NBA Live         34.70
# 35        PGA Tour         32.74
# 31   NCAA Football         32.53
# 33             NHL         23.89

# %%
dudu = sns.color_palette("twilight_r", 10).as_hex()
print(dudu)
# Out:
# ['#d2b7a5', '#c48065', '#a94950', '#7b2150', '#41123d', '#3e1150', '#5b3196', '#6068b6', '#759ac1', '#adc3cd']

# %%
twilight_r = ['#d2b7a5', '#c48065', '#a94950', '#7b2150', '#41123d', 
              '#3e1150', '#5b3196', '#6068b6', '#759ac1', '#adc3cd']
sales = [163.79, 122.65, 91.55, 65.29, 47.25, 37.77, 34.70, 32.74, 32.53, 23.89]
labels = ['FIFA', 'Madden NFL', 'Need for Speed', 'The Sims', 'Battlefield',
          'Medal of Honor', 'NBA Live', 'PGA Tour', 'NCAA Football', 'NHL']

fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(sales,
        colors = twilight_r,
        labels = labels,
        autopct='%1.1f%%')
circle = plt.Circle( (0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Top 10 Franchise Sales - Electronic Arts', loc = 'center', fontsize = 20)
plt.show()

# %% [markdown]
# Like Nintendo, EA publishes more games under their franchises than non-franchise where the huge majority of their sales come from. Interestingly though, EA does not have a top-selling franchise with a huge lead like the other two. Its best-selling franchise goes to FIFA, which contributes to one-quarter of the total sales, followed closely by Madden NFL. With this we can also see why the 'Sport' genre is the best-selling genre out of the 12. Both can also be considered EA's steady sources of income given their annual releases.
