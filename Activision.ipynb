# %% [markdown]
# # Activision

# %% [markdown]
# Founded in 1979 by former Atari game developers, Activision Publishing, Inc. is a California-based American video game publisher which serves as the publishing business for its parent company, Activision Blizzard, and consists of several subsidiary studios. It was the first independent, third-party, console video game developer and is one of the largest largest third-party video game publishers in the world, having been the top United States publisher in 2016.
#
# The company had gone through several drastic events and changes during its initial years - the 1983 video game crash, a management shift and rename, falling into debt and a subsequent restructure -  but through various mergers and acquisitions, Activision has managed to acquire various types of intellectual property, including successful games series such as Tony Hawk's, Call of Duty, Guitar Hero and Warcraft. A subsequent merger with Vivendi Games, leading to the formation of Activision Blizzard, also enabled Activision to manage numerous third-party studios and publishes all games beside those created by Blizzard.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
clean_df = pd.read_csv("/Users/jojotan/Documents/Portfolio/Video_Games/clean_vgsales.csv")
clean_df = clean_df.astype({"Year": int})

# %%
activision_df = clean_df[clean_df['Main Publisher'] == 'Activision']

# %%
activision_df['Franchise'] = pd.np.where(activision_df.Name.str.contains('Call of Duty'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Call Of Duty 2: Big Red One'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('3D Ultra Minigolf'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Assault Heroes'), 'Y',
                             pd.np.where(activision_df.Name.str.contains("Cabela's"), 'Y',
                             pd.np.where(activision_df.Name.str.contains('City Building'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Crash Bandicoot'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Diablo'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('Empire Earth'), 'Y', 
                             pd.np.where(activision_df.Name.str.contains('Geometry Wars'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Guitar Hero'), 'Y',   
                             pd.np.where(activision_df.Name.str.contains("King's Quest"), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Overwatch'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('Pitfall'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('Police Quest'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Soldier of Fortune'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('Space Quest'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Spider-Man'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('Skylanders'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Spyro'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('StarCraft'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Tenchu'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Teenage Mutant Ninja Turtles'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('Tony Hawk'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('True Crime'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Ultimate Soccer Manager'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Warcraft'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('Zork'), 'Y',
                             pd.np.where(activision_df.Name.str.contains('Doom'), 'Y',            
                             pd.np.where(activision_df.Name.str.contains('Prototype'), 'Y', 'N'
                             ))))))))))))))))))))))))))))))
# Out:
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_11655/83876129.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   activision_df['Franchise'] = pd.np.where(activision_df.Name.str.contains('Call of Duty'), 'Y',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_11655/83876129.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(activision_df.Name.str.contains('Call Of Duty 2: Big Red One'), 'Y',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_11655/83876129.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(activision_df.Name.str.contains('3D Ultra Minigolf'), 'Y',
# ...

# %%
activision_df['Franchise Name'] = pd.np.where(activision_df.Name.str.contains('Call of Duty'), 'Call of Duty',
                                  pd.np.where(activision_df.Name.str.contains('Doom'), 'Doom',
                                  pd.np.where(activision_df.Name.str.contains('Prototype'), 'Prototype',            
                                  pd.np.where(activision_df.Name.str.contains('3D Ultra Minigolf'), '3D Ultra Minigolf',
                                  pd.np.where(activision_df.Name.str.contains('Assault Heroes'), 'Assault Heroes',
                                  pd.np.where(activision_df.Name.str.contains("Cabela's"), "Cabela's",
                                  pd.np.where(activision_df.Name.str.contains('City Building'), 'City Building',
                                  pd.np.where(activision_df.Name.str.contains('Crash Bandicoot'), 'Crash Bandicoot', 
                                  pd.np.where(activision_df.Name.str.contains('Diablo'), 'Diablo',
                                  pd.np.where(activision_df.Name.str.contains('Empire Earth'), 'Empire Earth', 
                                  pd.np.where(activision_df.Name.str.contains('Geometry Wars'), 'Geometry Wars',
                                  pd.np.where(activision_df.Name.str.contains('Guitar Hero'), 'Guitar Hero',   
                                  pd.np.where(activision_df.Name.str.contains("King's Quest"), "King's Quest",
                                  pd.np.where(activision_df.Name.str.contains('Overwatch'), 'Overwatch',            
                                  pd.np.where(activision_df.Name.str.contains('Pitfall'), 'Pitfall',            
                                  pd.np.where(activision_df.Name.str.contains('Police Quest'), 'Police Quest',
                                  pd.np.where(activision_df.Name.str.contains('Soldier of Fortune'), 'Soldier of Fortune',            
                                  pd.np.where(activision_df.Name.str.contains('Space Quest'), 'Space Quest',
                                  pd.np.where(activision_df.Name.str.contains('Spider-Man'), 'Spider-Man',            
                                  pd.np.where(activision_df.Name.str.contains('Skylanders'), 'Skylanders',
                                  pd.np.where(activision_df.Name.str.contains('Spyro'), 'Spyro',
                                  pd.np.where(activision_df.Name.str.contains('StarCraft'), 'StarCraft',
                                  pd.np.where(activision_df.Name.str.contains('Tenchu'), 'Tenchu',
                                  pd.np.where(activision_df.Name.str.contains('Teenage Mutant Ninja Turtles'), 'Teenage Mutant Ninja Turtles',            
                                  pd.np.where(activision_df.Name.str.contains('Tony Hawk'), 'Tony Hawk',
                                  pd.np.where(activision_df.Name.str.contains('True Crime'), 'True Crime',
                                  pd.np.where(activision_df.Name.str.contains('Ultimate Soccer Manager'), 'Ultimate Soccer Manager',
                                  pd.np.where(activision_df.Name.str.contains('Warcraft'), 'Warcraft',
                                  pd.np.where(activision_df.Name.str.contains('Zork'), 'Zork', 'N.A.'
                                  )))))))))))))))))))))))))))))
# Out:
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_11655/137361595.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   activision_df['Franchise Name'] = pd.np.where(activision_df.Name.str.contains('Call of Duty'), 'Call of Duty',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_11655/137361595.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(activision_df.Name.str.contains('Doom'), 'Doom',
# /var/folders/l4/snqmxyzx0fdd92ms959qvmdh0000gn/T/ipykernel_11655/137361595.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(activision_df.Name.str.contains('Prototype'), 'Prototype',
# ...

# %%
activision_df.loc[activision_df['Name'].str.contains('StarCraft II'), 'Franchise Name'] = 'StarCraft II'
activision_df.loc[activision_df['Name'].str.contains('Call Of Duty 2: Big Red One'), 'Franchise Name'] = 'Call of Duty'
# Out:
# /Users/jojotan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
#activision_df.to_csv('Activision.csv', index=False)

# %%
actv_genre = activision_df['Genre'].value_counts()
actv_genre
# Out:
# Action          312
# Sports          168
# Shooter         167
# Misc            104
# Racing           74
# Platform         60
# Role-Playing     41
# Adventure        25
# Simulation       23
# Strategy         23
# Fighting          7
# Puzzle            7
# Name: Genre, dtype: int64

# %%
inferno12 = ['#0e092b', '#2d0b59', '#4f0d6c', '#6d186e', '#8d2369', '#ad305d', 
             '#c83f4b', '#e15635', '#f2741c', '#fb9606', '#fbbc21', '#f3e35a']
labels = ['Action', 'Sports', 'Shooter', 'Misc', 'Racing', 'Platform',
          'Role-Playing', 'Adventure', 'Strategy', 'Simulation', 'Fighting', 'Puzzle']

fig, ax = plt.subplots(figsize=(20, 12))
plt.pie(actv_genre,
        colors = inferno12,
        labels = labels,
        autopct='%1.1f%%')
circle = plt.Circle( (0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Game Genre Distribution - Activision', loc = 'center', fontsize = 20)
plt.show()

# %%
activision_df.head(10)
#top 10 best-selling games for Activision
# Out:
#     Rank                            Name Platform  Year    Genre  \
# 29    30  Call of Duty: Modern Warfare 3     X360  2011  Shooter
# 31    32         Call of Duty: Black Ops     X360  2010  Shooter
# 33    34       Call of Duty: Black Ops 3      PS4  2015  Shooter
# 34    35      Call of Duty: Black Ops II      PS3  2012  Shooter
# 35    36      Call of Duty: Black Ops II     X360  2012  Shooter
# 36    37  Call of Duty: Modern Warfare 2     X360  2009  Shooter
# 37    38  Call of Duty: Modern Warfare 3      PS3  2011  Shooter
# 40    41         Call of Duty: Black Ops      PS3  2010  Shooter
# 55    56  Call of Duty: Modern Warfare 2      PS3  2009  Shooter
# 61    62            Call of Duty: Ghosts     X360  2013  Shooter
#
#    Main Publisher   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 29     Activision  Activision      9.03      4.28      0.13         1.32
# 31     Activision  Activision      9.67      3.73      0.11         1.13
# ...

# %% [markdown]
# Since the top 10 includes same game titles due to the different platforms that they are released on, we will use pivot table to consolidate and sum up the total global sales for each game instead.

# %%
actv_top_selling = pd.pivot_table(activision_df,
                                  index = ["Name", "Franchise Name", "Genre"],
                                  values=["Global_Sales"],
                                  aggfunc=[np.sum])
actv_top_selling = actv_top_selling.reset_index()
actv_top_selling = actv_top_selling.droplevel(1, axis = 1)
actv_top_selling.columns = ['Name', 'Franchise Name', 'Genre', 'Total Global Sales']
actv_top_selling.sort_values(by = ['Total Global Sales'],
                             ascending = False,
                             inplace = True)

actv_top_selling.head(10)
# Out:
#                                  Name Franchise Name    Genre  \
# 77            Call of Duty: Black Ops   Call of Duty  Shooter
# 83     Call of Duty: Modern Warfare 3   Call of Duty  Shooter
# 79         Call of Duty: Black Ops II   Call of Duty  Shooter
# 81               Call of Duty: Ghosts   Call of Duty  Shooter
# 78          Call of Duty: Black Ops 3   Call of Duty  Shooter
# 82     Call of Duty: Modern Warfare 2   Call of Duty  Shooter
# 76     Call of Duty: Advanced Warfare   Call of Duty  Shooter
# 74     Call of Duty 4: Modern Warfare   Call of Duty  Shooter
# 142  Guitar Hero III: Legends of Rock    Guitar Hero     Misc
# 90         Call of Duty: World at War   Call of Duty  Shooter
#
#      Total Global Sales
# 77                31.03
# 83                30.83
# 79                29.72
# 81                27.38
# 78                25.32
# 82                25.09
# 76                21.90
# 74                18.25
# 142               16.39
# 90                15.87

# %%
sns.barplot(data = activision_df, 
            x = 'Genre', 
            y = 'Global_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre Globally - Activision", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre Globally - Activision')

# %%
platform_games = activision_df[activision_df['Genre'] == 'Action']
platform_games.head(10)
# Out:
#      Rank                                         Name Platform  Year   Genre  \
# 241   242                        Spider-Man: The Movie      PS2  2002  Action
# 324   325  LEGO Indiana Jones: The Original Adventures     X360  2008  Action
# 390   391                                 Spider-Man 2      PS2  2004  Action
# 411   412                    True Crime: Streets of LA      PS2  2003  Action
# 441   442                                   Spider-Man       PS  2000  Action
# 458   459                                Kung Fu Panda     X360  2008  Action
# 512   513                Skylanders: Spyro's Adventure      Wii  2011  Action
# 571   572                            Skylanders Giants      Wii  2012  Action
# 723   725  LEGO Indiana Jones: The Original Adventures       DS  2008  Action
# 851   853                    Tenchu: Stealth Assassins       PS  1997  Action
#
#     Main Publisher   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# Unlike the distribution of its released games' genres, Activision's best-selling genre belongs to the 'shooter' category which constituted to 16.5% of the entire mix - almost half of the most released genre, 'Action'. We can attribute this to its highly successful franchise, 'Call of Duty', which also happens to be the publisher's best-selling franchise.
#
# The most released genre, 'Action', trails behind in second place at almost half of the total global sales of the first place, with sales from several franchises and spinoffs of popular and successful animation / movies.
#
# The trend for the first and second best-selling genres is uniform in all four regions examined with the 'Shooter' genre holding a lead of almost twice the total sales of the 'Action' genre, further proving Call of Duty's success and popularity.

# %%
sns.set(font_scale = 1)
sns.barplot(data = activision_df, 
            x = 'Genre', 
            y = 'NA_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in North America - Activision", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in North America - Activision')

# %%
sns.barplot(data = activision_df, 
            x = 'Genre', 
            y = 'EU_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Europe - Activision", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Europe - Activision')

# %%
sns.barplot(data = activision_df, 
            x = 'Genre', 
            y = 'JP_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Japan - Activision", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Japan - Activision')

# %%
sns.barplot(data = activision_df, 
            x = 'Genre', 
            y = 'Other_Sales',
            palette = sns.color_palette('icefire', n_colors = 12),
            estimator = sum,
            ci = None).set_title("Sales by Genre in Other Regions - Activision", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'Sales by Genre in Other Regions - Activision')

# %%
fig, ax = plt.subplots(figsize=(50, 25))
sns.set(font_scale = 3)
sns.lineplot(data = activision_df, 
             x = 'Year', 
             y = 'Global_Sales', 
             linewidth = 5, 
             color = '#bc3754',
             estimator = sum,
             ci = None).set_title('Global Sales Across the Years - Activision', fontdict = {'size': 45})
# Out:
# Text(0.5, 1.0, 'Global Sales Across the Years - Activision')

# %%
print('Earliest Year Recorded:', activision_df.Year.min())
print('Latest Year Recorded:', activision_df.Year.max())
# Out:
# Earliest Year Recorded: 1980
# Latest Year Recorded: 2016

# %%
activision_df2 = activision_df.drop(['Rank', 'Global_Sales', 'Publisher'], axis = 1)
activision_df2 = activision_df2.melt(id_vars = ['Name', 'Platform', 'Year', 'Genre', 'Main Publisher', 'Franchise', 'Franchise Name'],
                                     var_name = 'Region',
                                     value_name = 'Total Sales')
activision_df2.loc[activision_df2['Region'] == 'NA_Sales', 'Region'] = 'NA'
activision_df2.loc[activision_df2['Region'] == 'EU_Sales', 'Region'] = 'EU'
activision_df2.loc[activision_df2['Region'] == 'JP_Sales', 'Region'] = 'JP'
activision_df2.loc[activision_df2['Region'] == 'Other_Sales', 'Region'] = 'Others'

# %%
fig, ax = plt.subplots(figsize=(50, 25))
sns.set(font_scale = 3)
sns.lineplot(data = activision_df2, 
             x = 'Year', 
             y = 'Total Sales',
             hue = 'Region',
             linewidth = 5, 
             palette = sns.color_palette('plasma', 4),
             estimator = sum,
             ci = None).set_title('Sales by Region Across the Years - Activision', fontdict = {'size': 45})
# Out:
# Text(0.5, 1.0, 'Sales by Region Across the Years - Activision')

# %%
sales_figures = pd.pivot_table(activision_df,
                               index = ['Year'],
                               values = ['Global_Sales'],
                               aggfunc = np.sum)
sales_figures = sales_figures.reset_index()
sales_figures.sort_values(by = ['Global_Sales'], 
                              ascending = False,
                              inplace = True)

sales_figures.head(6)
# Out:
#     Year  Global_Sales
# 25  2009         81.35
# 24  2008         68.87
# 26  2010         65.63
# 23  2007         64.45
# 28  2012         53.25
# 27  2011         51.74

# %%
actv_07_12 = activision_df[activision_df.Year.isin(['2007', '2008', '2009', '2010', '2011', '2012'])]

actv_07_12 = pd.pivot_table(actv_07_12,
                            index = ["Name", 'Franchise Name', "Year", "Platform"],
                            values=["Global_Sales"],
                            aggfunc=[np.sum])

actv_07_12 = actv_07_12.reset_index()
actv_07_12 = actv_07_12.droplevel(1, axis = 1)
actv_07_12.columns = ['Name', 'Franchise Name', 'Year', 'Platform', 'Total Global Sales']
actv_07_12.sort_values(by = ['Total Global Sales'], 
                              ascending = False,
                              inplace = True)

actv_07_12.head(10)
# Out:
#                                Name Franchise Name  Year Platform  \
# 119  Call of Duty: Modern Warfare 3   Call of Duty  2011     X360
# 108         Call of Duty: Black Ops   Call of Duty  2010     X360
# 110      Call of Duty: Black Ops II   Call of Duty  2012      PS3
# 112      Call of Duty: Black Ops II   Call of Duty  2012     X360
# 115  Call of Duty: Modern Warfare 2   Call of Duty  2009     X360
# 117  Call of Duty: Modern Warfare 3   Call of Duty  2011      PS3
# 106         Call of Duty: Black Ops   Call of Duty  2010      PS3
# 114  Call of Duty: Modern Warfare 2   Call of Duty  2009      PS3
# 102  Call of Duty 4: Modern Warfare   Call of Duty  2007     X360
# 129      Call of Duty: World at War   Call of Duty  2008     X360
#
#      Total Global Sales
# 119               14.76
# 108               14.64
# 110               14.03
# 112               13.73
# 115               13.51
# 117               13.46
# 106               12.73
# 114               10.69
# ...

# %%
actv_07_12['Year'].value_counts()
#count is inclusive of same game titles published on multiple platforms
# Out:
# 2009    128
# 2008     97
# 2010     93
# 2007     80
# 2011     75
# 2012     42
# Name: Year, dtype: int64

# %%
franchise_sales_07_12 = actv_07_12[actv_07_12['Franchise Name'] != 'N.A.']
franchise_sales_07_12 = pd.pivot_table(franchise_sales_07_12,
                                       index = ['Franchise Name'],
                                       values = ['Total Global Sales'],
                                       aggfunc = np.sum)
franchise_sales_07_12 = franchise_sales_07_12.reset_index()
franchise_sales_07_12.sort_values(by = ['Total Global Sales'],
                                  ascending = False,
                                  inplace = True)
franchise_sales_07_12.head(10)
# Out:
#    Franchise Name  Total Global Sales
# 1    Call of Duty              158.66
# 3     Guitar Hero               51.34
# 6      Skylanders               11.03
# 0        Cabela's               10.75
# 8      Spider-Man               10.53
# 11       Warcraft                9.32
# 10      Tony Hawk                5.62
# 2          Diablo                5.20
# 9    StarCraft II                4.83
# 5       Prototype                4.20

# %%
actv_2009 = actv_07_12[actv_07_12['Year'] == 2009]

actv_2009 = pd.pivot_table(actv_2009,
                           index = ["Name", 'Franchise Name', "Year"],
                            values=["Total Global Sales"],
                            aggfunc=[np.sum])

actv_2009 = actv_2009.reset_index()
actv_2009 = actv_2009.droplevel(1, axis = 1)
actv_2009.columns = ['Name', 'Franchise Name', 'Year', 'Total Global Sales']
actv_2009.sort_values(by = ['Total Global Sales'], 
                      ascending = False,
                      inplace = True)

actv_2009
# Out:
#                                                  Name Franchise Name  Year  \
# 9                      Call of Duty: Modern Warfare 2   Call of Duty  2009
# 24      LEGO Indiana Jones 2: The Adventure Continues           N.A.  2009
# 15                                      Guitar Hero 5    Guitar Hero  2009
# 4                                           Band Hero           N.A.  2009
# 13                                            DJ Hero           N.A.  2009
# 3                            Bakugan: Battle Brawlers           N.A.  2009
# 26                        Marvel: Ultimate Alliance 2           N.A.  2009
# 17                             Guitar Hero: Metallica    Guitar Hero  2009
# 36  Transformers: Revenge of the Fallen (XBox 360,...           N.A.  2009
# 40                                        [Prototype]      Prototype  2009
# 7                       Cabela's Big Game Hunter 2010       Cabela's  2009
# ...

# %% [markdown]
# Like the other two publishers, the North American market is the biggest for Activision. Its highest sales recorded between 1980 to 2016 were from 2007 to 2012, with its peak in 2009, when the number of games released was the highest, compared to the rest. The high amount of sales could largely be attributed to the release of 'Call of Duty: Modern Warfare II' which contributed to the majority of the sales for the year. The game had received 'universal acclaim' and the success could have been built on the success and the popularity of its prequel 'Call of Duty 4: Modern Warfare' which was released two years prior in 2007.
#
# 'Call of Duty' was also Activision's reigning franchise during the six-year period, with sales figures triple that of its second place, 'Guitar Hero'. It is interesting to note as well, that the recession did not seem to affect the overall sales in this case as there was actually an increase from 2007 to 2008 - when the recession hit - before increasing further to its peak in 2009.

# %% [markdown]
# #### Franchise Sales

# %%
franchise_release = activision_df['Franchise'].value_counts()
franchise_release
# Out:
# N    635
# Y    376
# Name: Franchise, dtype: int64

# %%
whew = ['#ae7181', '#8eab12'] #mauve and pea green
labels = ['Franchise', 'Non-Franchise']
stats = [376, 635]
fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(stats,
        colors = whew,
        labels = labels,
        autopct='%1.1f%%')
plt.title('Game Release Distribution - Activision', loc = 'center', fontsize = 20)
plt.show()

# %%
franchise_sales = pd.pivot_table(activision_df,
                                index = ['Franchise'],
                                values = ['Global_Sales'],
                                aggfunc = np.sum)
franchise_sales = franchise_sales.reset_index()
franchise_sales.sort_values(by = ['Global_Sales'],
                           ascending = False,
                           inplace = True)
franchise_sales
# Out:
#   Franchise  Global_Sales
# 1         Y        507.60
# 0         N        228.28

# %%
whew = ['#ae7181', '#8eab12'] #mauve and pea green
amounts = [507.60, 228.28]
labels = ['Franchise', 'Non-Franchise']
fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(amounts,
        colors = whew,
        labels = labels,
        autopct='%1.1f%%')
plt.title('Game Sales Contribution - Activision', loc = 'center', fontsize = 20)
plt.show()

# %%
franchise_sales = activision_df[activision_df['Franchise'] == 'Y']
top_franchise = pd.pivot_table(franchise_sales,
                               index = ['Franchise Name'],
                               values = ['Global_Sales'],
                               aggfunc = np.sum)
top_franchise = top_franchise.reset_index()
top_franchise.sort_values(by = ['Global_Sales'],
                          ascending = False,
                          inplace = True)
top_franchise.head(10)
# Out:
#    Franchise Name  Global_Sales
# 1    Call of Duty        251.56
# 15      Tony Hawk         54.86
# 4     Guitar Hero         53.36
# 10     Spider-Man         36.08
# 17       Warcraft         24.20
# 8      Skylanders         23.92
# 0        Cabela's         15.83
# 2          Diablo         12.67
# 12   StarCraft II          7.01
# 6         Pitfall          6.79

# %%
dudu = sns.color_palette("twilight_r", 10).as_hex()
print(dudu)
# Out:
# ['#d2b7a5', '#c48065', '#a94950', '#7b2150', '#41123d', '#3e1150', '#5b3196', '#6068b6', '#759ac1', '#adc3cd']

# %%
twilight_r = ['#d2b7a5', '#c48065', '#a94950', '#7b2150', '#41123d', 
              '#3e1150', '#5b3196', '#6068b6', '#759ac1', '#adc3cd']
sales = [251.56, 54.86, 53.36, 36.08, 24.20, 23.92, 15.83, 12.67, 7.01, 6.79]
labels = ['Call of Duty', 'Tony Hawk', 'Guitar Hero', 'Spider-Man', 'Warcraft', 
          'Skylanders', "Cabela's", 'Diablo', 'StarCraft II', 'Pitfall']

fig, ax = plt.subplots(figsize=(20, 12))
sns.set(font_scale = 1.2)
plt.pie(sales,
        colors = twilight_r,
        labels = labels,
        autopct='%1.1f%%')
circle = plt.Circle( (0,0), 0.7, color = 'white')
p = plt.gcf()
p.gca().add_artist(circle)
plt.title('Top 10 Franchise Sales - Activision', loc = 'center', fontsize = 20)
plt.show()

# %% [markdown]
# While non-franchises contributed mostly to Activision's game release distribution - unlike Nintento and EA where more games under franchises were released - the exact opposite is true when it comes to total sales contribution between the two (i.e. franchise and non-franchise), with the distribution almost mirrored.
#
# Unsurprisingly, 'Call of Duty' is the leading franchise amongst the top ten and contributes more than half of the total sales. It takes first place with sales figures almost five times than that of the second place, 'Tony Hawk'. With Xbox 360 being Activision's best-selling platform, we can also assume that majority of CoD players use the console.
#
# Taking all observations so far into consideration, it is safe to say the 'Call of Duty' franchise is basically Activision's steadiest and main source of income - which also puts pressure to ensure that the games' quality is constantly being improved on, or at the very least, maintained so as to retain the franchise's popularity.

# %% [markdown]
# #### Platform Sales

# %%
platform_sales = pd.pivot_table(activision_df, 
                                index = ['Platform'],
                                values = ['Global_Sales'],
                                aggfunc = np.sum)
platform_sales = platform_sales.reset_index()
platform_sales.sort_values(by = ['Global_Sales'],
                           ascending = False,
                           inplace = True)
platform_sales
# Out:
#    Platform  Global_Sales
# 17     X360        160.27
# 11      PS3        127.55
# 10      PS2         87.65
# 15      Wii         65.13
# 8        PC         48.11
# 3        DS         42.11
# 12      PS4         40.26
# 18       XB         33.06
# 9        PS         30.26
# 19     XOne         23.55
# 0      2600         19.42
# 5       GBA         15.39
# 6        GC         13.52
# 13      PSP         10.92
# 7       N64          6.58
# 1       3DS          4.66
# 16     WiiU          4.15
# 14      PSV          1.86
# 4        GB          1.33
# 2        DC          0.10

# %%
sns.set(font_scale = 1)
sns.barplot(data = platform_sales, 
            x = 'Global_Sales', 
            y = 'Platform',
            orient = 'h',
            palette = sns.color_palette('copper_r', n_colors = 20),
            estimator = sum,
            ci = None).set_title("All-Time Sales by Platform - Activision", fontdict = {'size': 17})
# Out:
# Text(0.5, 1.0, 'All-Time Sales by Platform - Activision')
